# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/PYTHON PROJRCT/laptop_price.csv",encoding='latin')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: count, Length: 618, dtype: int64

# %% [markdown]
# #Data cleaning

# %%
df.drop(columns = ['laptop_ID','Product'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1274, 11)

# %%
df.sample(3)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 1099    Asus    Gaming    17.3  IPS Panel Full HD 1920x1080
# 497       HP  Notebook    14.0            Full HD 1920x1080
# 1242    Acer  Notebook    15.6                     1366x768
#
#                               Cpu   Ram                Memory  \
# 1099  Intel Core i7 6700HQ 2.6GHz  16GB  128GB SSD +  1TB HDD
# 497    Intel Core i7 7600U 2.8GHz   8GB               1TB SSD
# 1242   Intel Core i3 6006U 2.0GHz   4GB             500GB HDD
#
#                           Gpu       OpSys  Weight  Price_euros
# 1099  Nvidia GeForce GTX 980M  Windows 10   4.3kg       2299.0
# 497     Intel HD Graphics 620  Windows 10  1.48kg       1749.0
# 1242    Intel HD Graphics 520       Linux   2.4kg        361.8

# %%
# 89.07 INR >>> 1 euro
# 499.0*89.07 =  INR

# %%
round(df['Price_euros'] *89.07)
# Out:
# 0       119326.0
# 1        80069.0
# 2        51215.0
# 3       226011.0
# 4       160647.0
#           ...
# 1269     64159.0
# 1270     56827.0
# 1271    133516.0
# 1272     20397.0
# 1273     68049.0
# Name: Price_euros, Length: 1274, dtype: float64

# %%
df.sample(3)
# Out:
#     Company  TypeName  Inches   ScreenResolution                          Cpu  \
# 861      HP  Notebook    15.6  Full HD 1920x1080   Intel Core i5 7300U 2.6GHz
# 77     Dell  Notebook    15.6  Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
# 790    Asus    Gaming    15.6  Full HD 1920x1080  Intel Core i7 7700HQ 2.8GHz
#
#      Ram                Memory                     Gpu       OpSys  Weight  \
# 861  8GB             256GB SSD      AMD Radeon R7 M465  Windows 10  1.84kg
# 77   8GB  128GB SSD +  1TB HDD  Intel UHD Graphics 620  Windows 10  2.02kg
# 790  8GB  128GB SSD +  1TB HDD  Nvidia GeForce GTX1060  Windows 10  2.24kg
#
#      Price_euros
# 861       1349.0
# 77         855.0
# 790       1339.0

# %%
df['Price_euros']=round(df['Price_euros'] *89.07)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg     119326.0
# 1        Intel HD Graphics 6000  macOS  1.34kg      80069.0
# ...

# %%
df['Price_euros']=round(df['Price_euros'] *89.07).astype('int')   #astype to converted into integer

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight  Price_euros
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg     10628367
# 1        Intel HD Graphics 6000  macOS  1.34kg      7131746
# ...

# %%
df.rename(columns={'Price_euros': 'Price'},inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight     Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  10628367
# 1        Intel HD Graphics 6000  macOS  1.34kg   7131746
# ...

# %%
#RAM converting from object to numeric column
df['Ram']
# Out:
# 0        8GB
# 1        8GB
# 2        8GB
# 3       16GB
# 4        8GB
#         ...
# 1269     4GB
# 1270     4GB
# 1271    16GB
# 1272     2GB
# 1273     6GB
# Name: Ram, Length: 1274, dtype: object

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     613
# 4GB     366
# 16GB    198
# 6GB      35
# 12GB     25
# 32GB     17
# 2GB      16
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
df[df['Ram']=='64GB']
# Out:
#      Company TypeName  Inches             ScreenResolution  \
# 1066    Asus   Gaming    17.3  IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram   Memory                      Gpu  \
# 1066  Intel Core i7 6820HK 2.7GHz  64GB  1TB SSD  Nvidia GeForce GTX 980
#
#            OpSys  Weight     Price
# 1066  Windows 10  3.58kg  31535501

# %%
a='4GB'
type(a)  #steps to shw how we will remove GB from RAM
# Out:
# str

# %%
a.replace("GB","")
# Out:
# '4'

# %%
#Str formating
name = 'zeeshan'
print(f"My name is {name}")
# Out:
# My name is zeeshan

# %%
print("my name is ",name)
# Out:
# my name is  zeeshan

# %%
(lambda a :a.replace("GB",""))('4GB')
# Out:
# '4'

# %%
df['Ram']=df['Ram'].apply(lambda a :a.replace("GB","")).astype('int')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  10628367
# 1        Intel HD Graphics 6000  macOS  1.34kg   7131746
# 2         Intel HD Graphics 620  No OS  1.86kg   4561720
# ...

# %%
df['Ram'].value_counts()
# Out:
# Ram
# 8     613
# 4     366
# 16    198
# 6      35
# 12     25
# 32     17
# 2      16
# 24      3
# 64      1
# Name: count, dtype: int64

# %%
#EDA if we want to perfor graph on this
df['Ram'].value_counts().plot(kind='bar') #this will give a frequency
# Out:
# <Axes: xlabel='Ram'>

# %%
df.describe()
# Out:
#             Inches          Ram         Price
# count  1274.000000  1274.000000  1.274000e+03
# mean     15.022449     8.444270  9.009007e+06
# std       1.429940     5.098291  5.558967e+06
# min      10.100000     2.000000  1.380407e+06
# 25%      14.000000     4.000000  4.838661e+06
# 50%      15.600000     8.000000  7.846176e+06
# 75%      15.600000     8.000000  1.187840e+07
# max      18.400000    64.000000  4.838621e+07

# %%
#How the ra colun is affecting my price column
sns.barplot(x=df['Ram'],y=df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
px.bar(x=df['Ram'],y=df['Price'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Weight converting from object to numeric column
df['Weight']
# Out:
# 0       1.37kg
# 1       1.34kg
# 2       1.86kg
# 3       1.83kg
# 4       1.37kg
#          ...
# 1269     2.2kg
# 1270     1.8kg
# 1271     1.3kg
# 1272     1.5kg
# 1273    2.19kg
# Name: Weight, Length: 1274, dtype: object

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     116
# 2.1kg      58
# 2.4kg      42
# 2.5kg      38
# 2.3kg      37
#          ...
# 1.14kg      1
# 3.8kg       1
# 1.19kg      1
# 1.55kg      1
# 4.0kg       1
# Name: count, Length: 179, dtype: int64

# %%
df['Weight']=df['Weight'].apply(lambda a :a.replace("kg","")).astype('float')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight     Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37  10628367
# 1        Intel HD Graphics 6000  macOS    1.34   7131746
# 2         Intel HD Graphics 620  No OS    1.86   4561720
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int64
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 119.4+ KB

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.20    119
# 2.10     58
# 2.00     45
# 2.40     42
# 2.50     38
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 3.25      1
# 2.34      1
# Name: count, Length: 171, dtype: int64

# %%
#EDA if we want to perfor graph on this
df['Weight'].value_counts().plot(kind='bar') #this will give a frequency
# Out:
# <Axes: xlabel='Weight'>

# %%
#How the ra colun is affecting my price column
sns.barplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.displot(x=df['Weight'],kde = True)

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
plt.scatter(x=df['Weight'],y=df['Price'])

# %%
px.scatter(x=df['Weight'],y=df['Price'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int64
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 119.4+ KB

# %%
df.sample()
# Out:
#     Company TypeName  Inches   ScreenResolution                    Cpu  Ram  \
# 435    Asus   Gaming    17.3  Full HD 1920x1080  AMD Ryzen 1600 3.2GHz    8
#
#                    Memory                Gpu       OpSys  Weight     Price
# 435  256GB SSD +  1TB HDD  AMD Radeon RX 580  Windows 10     3.2  13447254

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df.shape #before dropping
# Out:
# (1274, 11)

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %%
#filtering for the companys which are repeated more than 10 times in the dataset
df['Company']
# Out:
# 0        Apple
# 1        Apple
# 2           HP
# 3        Apple
# 4        Apple
#          ...
# 1269      Asus
# 1270    Lenovo
# 1271    Lenovo
# 1272    Lenovo
# 1273        HP
# Name: Company, Length: 1274, dtype: object

# %%
# which are repeated 10 times in dataset
df= df[df.groupby('Company')["Company"].transform('count')>10] #>>>transform this w.r.t count

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell       291
# Lenovo     289
# HP         268
# Asus       151
# Acer       101
# MSI         54
# Toshiba     48
# Apple       21
# Name: count, dtype: int64

# %%
df.shape #after dropping
# Out:
# (1223, 11)

# %%
sns.barplot(x=df['Company'],y=df['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
px.bar(x=df['Company'],y=df['Price'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.sample()
# Out:
#     Company  TypeName  Inches             ScreenResolution  \
# 171      HP  Notebook    17.3  IPS Panel Full HD 1920x1080
#
#                             Cpu  Ram   Memory             Gpu       OpSys  \
# 171  Intel Core i5 7200U 2.5GHz    6  2TB HDD  AMD Radeon 520  Windows 10
#
#      Weight    Price
# 171    2.71  5545498

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              687
# Gaming                200
# Ultrabook             171
# 2 in 1 Convertible    114
# Workstation            29
# Netbook                22
# Name: count, dtype: int64

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation=90) # Changed 'xsticks' to 'xticks'
plt.show()

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    636
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df= df[df.groupby('Inches')["Inches"].transform('count')>10] #>>>transform this w.r.t count

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    636
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# Name: count, dtype: int64

# %%
df.shape #after filtering
# Out:
# (1198, 11)

# %%
df['Inches'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
#inches vs price
sns.scatterplot(x=df['Inches'],y=df['Price'],palette='viridis')
plt.show()
# Out:
# <ipython-input-235-c181ee9a5e31>:2: UserWarning:
#
# Ignoring `palette` because no `hue` variable has been assigned.

# %%
#inches vs price
sns.barplot(x=df['Inches'],y=df['Price'],palette='viridis')
plt.show()
# Out:
# <ipython-input-236-23192a1cd772>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
df.sample()
# Out:
#     Company TypeName  Inches    ScreenResolution  \
# 376  Lenovo  Netbook    11.6  IPS Panel 1366x768
#
#                                       Cpu  Ram     Memory  \
# 376  Intel Celeron Quad Core N3450 1.1GHz    4  128GB SSD
#
#                        Gpu       OpSys  Weight    Price
# 376  Intel HD Graphics 500  Windows 10    1.59  4387232

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                491
# 1366x768                                         256
# IPS Panel Full HD 1920x1080                      217
# Full HD / Touchscreen 1920x1080                   44
# IPS Panel Full HD / Touchscreen 1920x1080         43
# 1600x900                                          22
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# ...

# %%
#PPI PIXES PER IMAGE(INCHES)>>>>#SPLIITING
a = 'IPS Panel Full HD / Touchscreen 1920x1080'
# X_1920,Y_1080

# %%
a
# Out:
# 'IPS Panel Full HD / Touchscreen 1920x1080'

# %%
a.split()
# Out:
# ['IPS', 'Panel', 'Full', 'HD', '/', 'Touchscreen', '1920x1080']

# %%
a.split()[-1]
# Out:
# '1920x1080'

# %%
a.split()[-1].split('x')
# Out:
# ['1920', '1080']

# %%
a.split()[-1].split('x')[0]  #x_res
# Out:
# '1920'

# %%
a.split()[-1].split('x')[1]  #y_res
# Out:
# '1080'

# %%
(lambda x:x.split()[-1].split('x')[0])('IPS Panel Touchscreen / 4K Ultra HD 3840x2160')
# Out:
# '3840'

# %%
(lambda x:x.split()[-1].split('x')[0])('1920x1080')
# Out:
# '1920'

# %%
(lambda x:x.split()[-1].split('x')[1])('1920x1080')
# Out:
# '1080'

# %%
df['x_res']=df['ScreenResolution'].apply((lambda x:x.split()[-1].split('x')[0])).astype('int')

# %%
df['y_res']=df['ScreenResolution'].apply((lambda x:x.split()[-1].split('x')[1])).astype('int')

# %%
def pow(a,b):
    pass

# %% [markdown]
# Pixels per inch (ppi) refers to the number of pixels contained within each inch of a digital image. It also refers to the set of number of pixels a screen can display . Generally speaking the higher the ppi , the better the image quality.

# %%
#now calculate the PPI and addded this column
#inches
#x_res
#y_res
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1198 entries, 0 to 1273
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1198 non-null   object
#  1   TypeName          1198 non-null   object
#  2   Inches            1198 non-null   float64
#  3   ScreenResolution  1198 non-null   object
#  4   Cpu               1198 non-null   object
#  5   Ram               1198 non-null   int64
#  6   Memory            1198 non-null   object
#  7   Gpu               1198 non-null   object
#  8   OpSys             1198 non-null   object
#  9   Weight            1198 non-null   float64
#  10  Price             1198 non-null   int64
#  11  x_res             1198 non-null   int64
#  12  y_res             1198 non-null   int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 131.0+ KB

# %%
df['ppi']=round(((df['x_res']**2)+(df['y_res']**2))**0.5/df['Inches'],2)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches                  ScreenResolution  \
# 836    Asus     Gaming    17.3                 Full HD 1920x1080
# 416    Dell   Notebook    13.3                          1366x768
# 258     MSI     Gaming    17.3                 Full HD 1920x1080
# 922      HP  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 203  Lenovo     Gaming    15.6       IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram                Memory  \
# 836  Intel Core i7 7700HQ 2.8GHz   16  256GB SSD +  1TB HDD
# 416     Intel Core i3 6006U 2GHz    4             128GB SSD
# 258  Intel Core i7 7700HQ 2.8GHz   16  512GB SSD +  1TB HDD
# 922   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 203  Intel Core i7 7700HQ 2.8GHz   16  512GB SSD +  1TB HDD
#
#                          Gpu       OpSys  Weight     Price  x_res  y_res  \
# 836  Nvidia GeForce GTX 1070  Windows 10    2.90  19191022   1920   1080
# ...

# %%
#PPI vs price analysis
df['Price'].value_counts()
# Out:
# Price
# 8718884     14
# 3958805     11
# 14272310    11
# 9512231     10
# 10305577    10
#             ..
# 2411748      1
# 6021488      1
# 14740372     1
# 9155238      1
# 6061124      1
# Name: count, Length: 759, dtype: int64

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
sns.regplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %% [markdown]
# #interview question
# it is hyperplane used to differentiate a cluster

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                491
# 1366x768                                         256
# IPS Panel Full HD 1920x1080                      217
# Full HD / Touchscreen 1920x1080                   44
# IPS Panel Full HD / Touchscreen 1920x1080         43
# 1600x900                                          22
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# ...

# %%
a = 'IPS Panel Full HD / Touchscreen 1920x1080'
#If there is IPS in this string return 1 else 0
(lambda a:1 if "IPS" in a else 0)('IPS Panel Full HD / Touchscreen 1920x1080')
# Out:
# 1

# %%
df['IPS']=df['ScreenResolution'].apply(lambda a:1 if "IPS" in a else 0)

# %%
df.sample(3)
# Out:
#       Company   TypeName  Inches                  ScreenResolution  \
# 763      Asus  Ultrabook    13.3      IPS Panel Quad HD+ 3200x1800
# 1028     Dell  Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 331   Toshiba   Notebook    15.6       IPS Panel Full HD 1920x1080
#
#                              Cpu  Ram     Memory                    Gpu  \
# 763   Intel Core i5 7200U 2.5GHz    8  256GB SSD  Intel HD Graphics 620
# 1028  Intel Core i5 7200U 2.5GHz    8  256GB SSD  Intel HD Graphics 620
# 331   Intel Core i5 7200U 2.5GHz    8  256GB SSD  Intel HD Graphics 620
#
#            OpSys  Weight     Price  x_res  y_res     ppi  IPS
# 763   Windows 10    1.20   8956879   3200   1800  276.05    1
# 1028  Windows 10    1.29  12883975   3200   1800  276.05    0
# 331   Windows 10    2.00   7481257   1920   1080  141.21    1

# %%
df['Touchscreen'] = df['ScreenResolution'].apply(lambda a:1 if "Touchscreen" in a else 0)

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %%
df.drop(columns = ['ScreenResolution','Inches','x_res','y_res'],inplace=True)

# %%
df.shape
# Out:
# (1198, 12)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     122
# Intel Core i5 8250U 1.6GHz      70
# Intel Core i7 8550U 1.8GHz      68
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core i5 2.0GHz             1
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 100, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
#clean this dataset with multiple filtering
#extract first 3 characters
a = 'Intel Core i5 7200U 2.5GHz'

# %%
a.split()   #to convert ur srng into list
# Out:
# ['Intel', 'Core', 'i5', '7200U', '2.5GHz']

# %%
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
" ".join(a.split()[0:3])
# Out:
# 'Intel Core i5'

# %%
(lambda a:" ".join(a.split()[0:3]))('Intel Core i5 7200U 2.5GHz')
# Out:
# 'Intel Core i5'

# %%
(lambda a:" ".join(a.split()[0:3]))('AMD E-Series E2-9000 2.2GHz')
# Out:
# 'AMD E-Series E2-9000'

# %%
df['Cpu']=df['Cpu'].apply(lambda a:" ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7               483
# Intel Core i5               409
# Intel Core i3               133
# Intel Celeron Dual           64
# Intel Pentium Quad           27
# AMD A9-Series 9420           11
# Intel Core M                 10
# AMD A6-Series 9220            8
# AMD A12-Series 9720P          7
# Intel Celeron Quad            5
# AMD A8-Series 7410            4
# Intel Pentium Dual            3
# AMD Ryzen 1700                3
# AMD A9-Series A9-9420         2
# Intel Xeon E3-1535M           2
# AMD A10-Series 9600P          2
# AMD E-Series 7110             2
# AMD A10-Series 9620P          2
# AMD A6-Series A6-9220         2
# AMD A10-Series A10-9620P      2
# Intel Xeon E3-1505M           2
# AMD E-Series E2-9000e         2
# AMD E-Series 9000e            1
# AMD Ryzen 1600                1
# AMD E-Series 6110             1
# AMD FX 9830P                  1
# AMD E-Series E2-6110          1
# AMD E-Series E2-9000          1
# AMD A6-Series 7310            1
# ...

# %%
df.shape
# Out:
# (1198, 12)

# %%
#biforgate the data #fetch the processor into new col
#will filter the AMD cpu w.r.t. the series
#AMD AMD A9-Series 9420 >> AMD A-series
#AMD E-Series 7110 >>AMB E-series
#AMD FX 8800P	>> AMD FX  series

# %%
def fetch_processor(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text.split()[0] == 'Intel':
    return 'Other Intel Processor'
  else:
      if text[4]=='E':
        return 'AMD E-series'
      elif text[4]=='A':
        return 'AMD A-series'
      elif text[4]=='F':
        return 'AMD FX-series'
      else:
        return 'AMD Ryzen-series'

# %%
fetch_processor('AMD A6-Series 7310')
# Out:
# 'AMD A-series'

# %%
a= 'Intel Celeron Dual'
a.split()[0]
# Out:
# 'Intel'

# %%
b = 'AMD E-Series E2-6110'
b[4]
# Out:
# 'E'

# %%
df['Cpu']=df['Cpu'].apply(fetch_processor)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i7            483
# Intel Core i5            409
# Intel Core i3            133
# Other Intel Processor    114
# AMD A-series              44
# AMD E-series               9
# AMD Ryzen-series           4
# AMD FX-series              2
# Name: count, dtype: int64

# %%
df['Cpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x=df['Cpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df['Gpu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620       262
# Intel HD Graphics 520       179
# Nvidia GeForce GTX 1050      65
# Intel UHD Graphics 620       64
# Nvidia GeForce GTX 1060      45
#                            ...
# AMD Radeon R5 520             1
# AMD Radeon R7                 1
# Intel HD Graphics 540         1
# Nvidia GeForce GTX 1070M      1
# Nvidia GeForce 960M           1
# Name: count, Length: 102, dtype: int64

# %%
a = 'Intel HD Graphics 620'

# %%
a.split()
# Out:
# ['Intel', 'HD', 'Graphics', '620']

# %%
a.split()[0:2]
# Out:
# ['Intel', 'HD']

# %%
" ".join(a.split()[0:2])
# Out:
# 'Intel HD'

# %%
(lambda a:" ".join(a.split()[0:3]))('Intel HD Graphics 620')
# Out:
# 'Intel HD Graphics'

# %%
df['Gpu']=df['Gpu'].apply(lambda a:" ".join(a.split()[0:2]))

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD          570
# Nvidia GeForce    353
# AMD Radeon        162
# Intel UHD          64
# Nvidia Quadro      31
# Intel Iris         10
# AMD FirePro         5
# AMD R4              1
# AMD R17M-M1-70      1
# Intel Graphics      1
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Gpu'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.sample()
# Out:
#      Company  TypeName            Cpu  Ram     Memory            Gpu  \
# 1017  Lenovo  Notebook  Intel Core i7   16  512GB SSD  Nvidia Quadro
#
#           OpSys  Weight     Price     ppi  IPS  Touchscreen
# 1017  Windows 7     2.4  23546545  254.67    1            0

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      997
# No OS            63
# Linux            58
# Windows 7        45
# Chrome OS        22
# macOS             8
# Mac OS X          3
# Windows 10 S      2
# Name: count, dtype: int64

# %%
#wherever we have win10 or w10s >>> win 10
#win 7 >> win 7
#if we have mac os x or macos >> mac os                this is how the opsys wriiten as
#no os >> no os
#chrome os/linux >> linux/chrome os

# %%
def os(text):
  if text == 'Windows 10' or text == 'Windows 10 S':
    return 'Windows 10'
  elif text == 'Windows 7':
    return 'Windows 7'
  elif text == 'Mac OS' or text == 'Mac OS X':
    return 'Mac OS'
  elif text == 'No OS':
    return 'No OS'
  elif text == 'Linux':
    return 'Linux'
  else:
    return 'Chrome OS'

# %%
os('Windows 10 S')
# Out:
# 'Windows 10'

# %%
df['OpSys']=df['OpSys'].apply(os)

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10    999
# No OS          63
# Linux          58
# Windows 7      45
# Chrome OS      30
# Mac OS          3
# Name: count, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation=90)
plt.show()

# %%
df[df['OpSys'] == 'Windows 10']['Price'].describe()
# Out:
# count    9.990000e+02
# mean     9.290016e+06
# std      5.221655e+06
# min      1.522474e+06
# 25%      5.355067e+06
# 50%      8.242894e+06
# 75%      1.189623e+07
# max      3.886605e+07
# Name: Price, dtype: float64

# %%
sns.displot(x=df['OpSys'], y=df['Price'])

# %%
df.sample(3)
# Out:
#      Company            TypeName            Cpu  Ram                Memory  \
# 1143      HP         Workstation  Intel Core i7    8             256GB SSD
# 414     Asus  2 in 1 Convertible  Intel Core i5    8             256GB SSD
# 1245    Asus              Gaming  Intel Core i7   16  256GB SSD +  1TB HDD
#
#                  Gpu       OpSys  Weight     Price     ppi  IPS  Touchscreen
# 1143   Nvidia Quadro   Windows 7    2.59  17683691  141.21    1            0
# 414         Intel HD  Windows 10    1.27   7362259  165.63    1            1
# 1245  Nvidia GeForce  Windows 10    2.50  12693544  141.21    1            0

# %%
#flast storage create a column
#ssd
#hdd
#hybrid (ssd+hdd)
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        387
# 1TB HDD                          213
# 500GB HDD                        122
# 512GB SSD                         99
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                28
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              13
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       7
# 64GB Flash Storage                 6
# 16GB Flash Storage                 6
# 256GB Flash Storage                5
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
new = df['Memory'].str.split('+',n=1,expand=True) # Assign the result of the split to the variable 'new'

# %%
df['first'] = new[0]
df['first']
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 4                 256GB SSD
# 5                 500GB HDD
#                ...
# 1269              500GB HDD
# 1270              128GB SSD
# 1271              512GB SSD
# 1272     64GB Flash Storage
# 1273                1TB HDD
# Name: first, Length: 1198, dtype: object

# %%
df['first'].str.strip()   #use to remove any white spaces #filter ur dat properly
# Out:
# 0                 128GB SSD
# 1       128GB Flash Storage
# 2                 256GB SSD
# 4                 256GB SSD
# 5                 500GB HDD
#                ...
# 1269              500GB HDD
# 1270              128GB SSD
# 1271              512GB SSD
# 1272     64GB Flash Storage
# 1273                1TB HDD
# Name: first, Length: 1198, dtype: object

# %%
df['first'].apply(lambda x:1 if "HDD" in x else 0)
# Out:
# 0       0
# 1       0
# 2       0
# 4       0
# 5       1
#        ..
# 1269    1
# 1270    0
# 1271    0
# 1272    0
# 1273    1
# Name: first, Length: 1198, dtype: int64

# %%
df['first'].str.replace(r'\D', '',regex=True) #regex used to validate manipulate strings and patterens in the text
# Out:
# 0       128
# 1       128
# 2       256
# 4       256
# 5       500
#        ...
# 1269    500
# 1270    128
# 1271    512
# 1272     64
# 1273      1
# Name: first, Length: 1198, dtype: object

# %%
#flast storage create a column
#ssd
#hdd
#hybrid (ssd+hdd)
new=df['Memory'].str.split('+',n=1,expand=True)
df['first']=new[0]
df['first']=df['first'].str.strip()
df['second']=new[1]

# Convert 'first' and 'second' to string type before applying lambda functions
df['first'] = df['first'].astype(str)
df['second'] = df['second'].astype(str)

df['Layer1HDD']=df['first'].apply(lambda x:1 if "HDD" in x else 0)
df['Layer1SSD']=df['first'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer1Hybrid']=df['first'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage']=df['first'].apply(lambda x:1 if "Flash Storage" in x else 0)

df['first']=df['first'].str.replace(r'\D', '',regex=True)

# Replace empty strings with "0" before stripping and applying lambda functions
df['second'].fillna("0", inplace=True)
df['second'] = df['second'].astype(str)  # Ensure 'second' is of type str

df['second']=df['second'].str.strip()
df['Layer2HDD'] = df['second'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer2SSD']=df['second'].apply(lambda x:1 if "SSD" in x else 0)
df['Layer2Hybrid']=df['second'].apply(lambda x:1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage']=df['second'].apply(lambda x:1 if "Flash Storage" in x else 0)

df['second']=df['second'].str.replace(r'\D', '',regex=True)

# Replace empty strings with 0 before converting to int
df['first'] = pd.to_numeric(df['first'], errors='coerce').fillna(0).astype(int)
df['second'] = pd.to_numeric(df['second'], errors='coerce').fillna(0).astype(int)

df['HDD']=df['first']*df['Layer1HDD']+df['second']*df['Layer2HDD']
df['SSD']=df['first']*df['Layer1SSD']+df['second']*df['Layer2SSD']
df['Hybrid']=df['first']*df['Layer1Hybrid']+df['second']*df['Layer2Hybrid']
df['Flash_Storage']=df['first']*df['Layer1Flash_Storage']+df['second']*df['Layer2Flash_Storage']

df.drop(columns = ['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage','Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-314-1151c8732f62>:22: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df.sample()
# Out:
#      Company TypeName            Cpu  Ram                Memory  \
# 1092    Asus   Gaming  Intel Core i7    8  256GB SSD +  1TB HDD
#
#                  Gpu       OpSys  Weight     Price     ppi  IPS  Touchscreen  \
# 1092  Nvidia GeForce  Windows 10     2.7  12685617  127.34    1            0
#
#       HDD  SSD  Hybrid  Flash_Storage
# 1092    1  256       0              0

# %%
df.to_csv('cleaned.csv')  #to explore the file

# %% [markdown]
# #LAMBDA THEORY

# %%
add  =lambda x,y :x+y

# %%
add(2,3)
# Out:
# 5

# %%
def add(x,y):
  return x+y

# %%
add (2,3)
# Out:
# 5
